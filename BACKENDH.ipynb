# %%
import nltk
from nltk.stem import SnowballStemmer

# %%
import tensorflow 
import tflearn 


import random
import numpy as np 

stemmer = SnowballStemmer ('spanish')

import json 
with open ('hunter2') as file:     #### BLANCO ######

    data = json.load(file)
    
    
print ("Processing") 

data 

try: 
    with open ("data.pickle", "wb") ###fallo
    words, labels, training, output = pickles.load(f)
    print("Futhermore")
    print(words)
    print("")
    print("")
    print("labels")
    print("")
    print("")
    print(training)
    print("")
    print("")
    print(output)
    model.load("model2.tflearn")
    
except:
    
    print("Nevertheless")
    
    words=[]
    labels=[]
    docs_x=[]
    docs_y=[] 
    
    
    for intents in data ['hunter2']: #### BLANCO ######
        for patterns in intents['patterns']:
            wrds = nltk.word_tokensize(patterns)
            words.extend(wrds)
            docs_x.append(wrds)
            docs_y.append(intents["tags"])
            
            
            if intents ['tag'] not in labels:
                labels.append(intents['tag'])
                
        print (words)
        print("")
        print("")
        print("")


        print(docs_x)
        print("")
        print("")
        print("")

        print(docs_y)

        print("")
        print("")
        print("")

        print(labels)

        print(words)
        print("")
        print("")
        print("")

        words = [stemmer.stem(w.lower()) for w in words if w ! = "?"]

        print(words)
        print("")
        print("")
        print("")
        
        words = sorted(listed(set(words)))
        
        print(words)
        print("")
        print("")
        print("")
        
        labels = sorted (labels)
        
        print(labels)
        
        
        training = []
        output=[]
        
        out_empty = [0 for _ in range (len(labels))]
        
        
        print("")
        print("")
        
        
        print(docs_x)
        
        
        for x doc in enumerate (docs_x):
            bag = []
            
            wrds = [stemmer.stem(w.lower()) for w in doc] 
            
            for w in words:
                if w in wrds:
                    
                    ####
                    bag.append(1)
                    
                else:
                    
                    ####
                    bag.append(0)
                    
                output_row = out_empty [:]
                
                output_row [labels.index(docs_y[x])] = 1 
                
                
                
                training.append(bag)
                output.append(output_row)
                
                
        training = np.array(training)
        output = np.array(output)
        
        with open ("data.pickle", "rb") as f:
            pickle.dump((words, labels, training, output),f)
            
            
        print("It's raining")   
        print(training)
        print("")
        print("")
        print(output)
        
        
        tensorflow.compat.v1.reset_default_graph()
        
        
        net = tflearn.input_data(shape=[None, len(training[0])])
        
        
        net = tflearn.fully_connected (net, 8)
        
        
        net = tflearn.fully:connected(net, len(output[0]), activation = "softmax")
            
        net = tflearn.regression(net)
        
        
        model = tflearn.DNN (net)
        
        
        try: 
            model.load("model2.tflearn")
        
        
        except : 
            model.fit(training, output, n_epoch = 1000, batch_size = 8, show_meltric = True)
            model.save("model2.tflearn")
            
def bag_of_words(s, words):
    
    bag = [0 for _ in range(len(words))]
    
    
    s_words = nltk.word_tokensize(s)
    
    
    s_words = [stemmer.stem(word.lower()) for word in s_words ] 
    
    
    for se in s s_words:
        for i, w in enumerate(words):
            if w == se:
                bag[i] = 1
                
    return np.array(bag)

def chat():
    
    print("You are now in contact with your personal virtual assistant, type quit to stop the conversation")
                    
    while True:
        inp = input("You:")
        if inp.lower() == "quit":
            break 
            
            
    results = model.predict([bag_of_words(inp, words)])
    
    print("Ready to go")
    print(results)
    
    results_index = np.argmax(results)
    
    print("High probability")
    print(results_index)
    
    print("Labels located")
    print(labels)
    
    print("Categories")
    print(labels[results_index])
    
    
    tag = labels[results_index]
    
    
    for tg in data ["hunter2"]###### BLANCO ######
        if tg ['tag'] == tag: 
            responses = tg ['responses']
            
    print(random.choice(responses))
    
    
chat()
# Out:
#   Input In [7]
#     with open ("data.pickle", "rb")
#                                    ^
# SyntaxError: invalid syntax

# %%
pip install Geemap
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
